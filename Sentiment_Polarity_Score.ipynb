# %% [markdown]
# <a href="https://colab.research.google.com/github/SrushtiMD/webdata_extraction/blob/main/Sentiment_Polarity_Score.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
#  **Sentiment Score - Positive Score, Negative Score, Polarity Score**

# %%
import numpy as np
import pandas as pd
import nltk
from nltk.sentiment.vader import SentimentIntensityAnalyzer
import re
from textblob import TextBlob
from wordcloud import WordCloud
import seaborn as sns
import matplotlib.pyplot as plt
import cufflinks as cf
# %matplotlib inline
from plotly.offline import init_notebook_mode, iplot
init_notebook_mode(connected = True)
cf.go_offline();
import plotly.graph_objs as go
from plotly.subplots import make_subplots

import warnings
warnings.filterwarnings("ignore")
warnings.warn("this will not show")

pd.set_option('display.max_columns', None)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.8.3.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.8.3.min']
#             }
#         });
# ...

# %%
import nltk
nltk.download('vader_lexicon')
# Out:
# [nltk_data] Downloading package vader_lexicon to /root/nltk_data...
# True

# %%
s = SentimentIntensityAnalyzer()

# %%
for i in range(1,114):
  filenum = i
  fileurl = "/content/drive/MyDrive/Data_Extraction/Extracted Files/" + str(filenum) + ".txt"
  file_read = open(fileurl)
  print(filenum)
  print(s.polarity_scores(file_read.read()))
# Out:
# 1
# {'neg': 0.044, 'neu': 0.811, 'pos': 0.145, 'compound': 0.9996}
# 2
# {'neg': 0.083, 'neu': 0.768, 'pos': 0.149, 'compound': 0.9984}
# 3
# {'neg': 0.036, 'neu': 0.889, 'pos': 0.075, 'compound': 0.9891}
# 4
# {'neg': 0.044, 'neu': 0.812, 'pos': 0.144, 'compound': 0.9995}
# 5
# {'neg': 0.049, 'neu': 0.805, 'pos': 0.146, 'compound': 0.9996}
# 6
# {'neg': 0.038, 'neu': 0.8, 'pos': 0.162, 'compound': 0.9996}
# 7
# {'neg': 0.025, 'neu': 0.874, 'pos': 0.101, 'compound': 0.9953}
# 8
# {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
# 9
# {'neg': 0.056, 'neu': 0.782, 'pos': 0.161, 'compound': 0.9982}
# 10
# {'neg': 0.046, 'neu': 0.807, 'pos': 0.147, 'compound': 0.9998}
# 11
# {'neg': 0.095, 'neu': 0.785, 'pos': 0.12, 'compound': 0.9955}
# 12
# {'neg': 0.052, 'neu': 0.814, 'pos': 0.134, 'compound': 0.9988}
# 13
# {'neg': 0.064, 'neu': 0.803, 'pos': 0.133, 'compound': 0.9983}
# 14
# {'neg': 0.036, 'neu': 0.821, 'pos': 0.143, 'compound': 0.9997}
# 15
# ...

# %%
for i in range(1, 114):
  filenum = i
  fileurl = "/content/drive/MyDrive/Data_Extraction/Extracted Files/" + str(filenum) + ".txt"
  file_read = open(fileurl)
  file_content = TextBlob(file_read.read())
  print("=============="+ str(filenum) + "=======================")
  print(file_content.sentiment.polarity)
# Out:
# ==============1=======================
# 0.13693643937761585
# ==============2=======================
# 0.07469251007613077
# ==============3=======================
# 0.11071141443590425
# ==============4=======================
# 0.14062977994227993
# ==============5=======================
# 0.05317796664120197
# ==============6=======================
# 0.11893904276647636
# ==============7=======================
# 0.14694743662134965
# ==============8=======================
# 0.0
# ==============9=======================
# 0.19017686550737403
# ==============10=======================
# 0.16784277669233422
# ==============11=======================
# 0.11554057756589406
# ==============12=======================
# 0.1209134401424121
# ==============13=======================
# 0.10389209862570851
# ==============14=======================
# 0.14755515318015325
# ==============15=======================
# 0.05736288732471939
# ==============16=======================
# 0.1761308203991131
# ...
